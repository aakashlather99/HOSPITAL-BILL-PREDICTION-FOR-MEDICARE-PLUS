# %%
# 📘 Hospital Bill Prediction for MediCarePlus
print('Hello from YBI Foundation 🚀')
# Out:
# Hello from YBI Foundation 🚀

# %%
#import library
import pandas as pd

# %%
#read dataset
df=pd.read_csv('/Hospital Bill Prediction for MediCarePlus.csv')

# %%
df.head()
# Out:
#   gender  age insurance_type diagnosis_type  procedures_count surgery_done  \
# 0   Male   79     Government      Maternity                 3          Yes
# 1  Other   70        Private     Cardiology                 3           No
# 2   Male    0     Government      Maternity                 3          Yes
# 3   Male   11     Government      Maternity                 5           No
# 4   Male    7            NaN        General                 1          Yes
#
#   icu_admission  length_of_stay_days  medications_count     room_type  \
# 0            No                    5                  6  General Ward
# 1            No                   11                  1  General Ward
# 2           Yes                    8                  4       Private
# 3            No                   17                 12  General Ward
# 4           Yes                    6                  5  General Ward
#
#    predicted_hospital_bill_inr
# 0                      41254.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   age                          1000 non-null   int64
#  2   insurance_type               801 non-null    object
#  3   diagnosis_type               1000 non-null   object
#  4   procedures_count             1000 non-null   int64
#  5   surgery_done                 1000 non-null   object
#  6   icu_admission                1000 non-null   object
#  7   length_of_stay_days          1000 non-null   int64
#  8   medications_count            1000 non-null   int64
#  9   room_type                    1000 non-null   object
#  10  predicted_hospital_bill_inr  1000 non-null   float64
# dtypes: float64(1), int64(4), object(6)
# memory usage: 86.1+ KB

# %%
df=df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 801 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       801 non-null    object
#  1   age                          801 non-null    int64
#  2   insurance_type               801 non-null    object
#  3   diagnosis_type               801 non-null    object
#  4   procedures_count             801 non-null    int64
#  5   surgery_done                 801 non-null    object
#  6   icu_admission                801 non-null    object
#  7   length_of_stay_days          801 non-null    int64
#  8   medications_count            801 non-null    int64
#  9   room_type                    801 non-null    object
#  10  predicted_hospital_bill_inr  801 non-null    float64
# dtypes: float64(1), int64(4), object(6)
# memory usage: 75.1+ KB

# %%
df.describe(include='all')
# Out:
#        gender         age insurance_type diagnosis_type  procedures_count  \
# count     801  801.000000            801            801        801.000000
# unique      3         NaN              2              5               NaN
# top      Male         NaN        Private     Cardiology               NaN
# freq      285         NaN            511            171               NaN
# mean      NaN   46.591760            NaN            NaN          1.977528
# std       NaN   26.163226            NaN            NaN          1.428984
# min       NaN    0.000000            NaN            NaN          0.000000
# 25%       NaN   23.000000            NaN            NaN          1.000000
# 50%       NaN   47.000000            NaN            NaN          2.000000
# 75%       NaN   70.000000            NaN            NaN          3.000000
# max       NaN   89.000000            NaN            NaN          8.000000
#
#        surgery_done icu_admission  length_of_stay_days  medications_count  \
# ...

# %%
#encoding
df['gender'].value_counts()
# Out:
# gender
# Male      285
# Female    268
# Other     248
# Name: count, dtype: int64

# %%
#dictionary to assign value to objects
{'Male':0,'Female':1}
# Out:
# {'Male': 0, 'Female': 1}

# %%
df['gender']=df['gender'].replace({'Male':0,'Female':1,'Other':2}).astype(int)

# %%
df['gender'].value_counts()
# Out:
# gender
# 0    285
# 1    268
# 2    248
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 801 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       801 non-null    int64
#  1   age                          801 non-null    int64
#  2   insurance_type               801 non-null    object
#  3   diagnosis_type               801 non-null    object
#  4   procedures_count             801 non-null    int64
#  5   surgery_done                 801 non-null    object
#  6   icu_admission                801 non-null    object
#  7   length_of_stay_days          801 non-null    int64
#  8   medications_count            801 non-null    int64
#  9   room_type                    801 non-null    object
#  10  predicted_hospital_bill_inr  801 non-null    float64
# dtypes: float64(1), int64(5), object(5)
# memory usage: 75.1+ KB

# %%
df['insurance_type'].value_counts()
# Out:
# insurance_type
# Private       511
# Government    290
# Name: count, dtype: int64

# %%
{'Government':0,'Private':1}
# Out:
# {'Government': 0, 'Private': 1}

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 801 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       801 non-null    int64
#  1   age                          801 non-null    int64
#  2   insurance_type               801 non-null    object
#  3   diagnosis_type               801 non-null    object
#  4   procedures_count             801 non-null    int64
#  5   surgery_done                 801 non-null    object
#  6   icu_admission                801 non-null    object
#  7   length_of_stay_days          801 non-null    int64
#  8   medications_count            801 non-null    int64
#  9   room_type                    801 non-null    object
#  10  predicted_hospital_bill_inr  801 non-null    float64
# dtypes: float64(1), int64(5), object(5)
# memory usage: 75.1+ KB

# %%
df['diagnosis_type'].value_counts()
# Out:
# diagnosis_type
# Cardiology     171
# Maternity      165
# Orthopedics    165
# Oncology       154
# General        146
# Name: count, dtype: int64

# %%
#change the data types from object to int
df['diagnosis_type']=df['diagnosis_type'].replace({'General':0,'Maternity':1,'Orthopedics':2,'Cardiology':3,'Oncology':4}).astype(int)

# %%
df['diagnosis_type'].value_counts()
# Out:
# diagnosis_type
# 3    171
# 1    165
# 2    165
# 4    154
# 0    146
# Name: count, dtype: int64

# %%
df['surgery_done']=df['surgery_done'].replace({'Yes':1,'No':0}).astype(int)

# %%
df['surgery_done'].value_counts()
# Out:
# surgery_done
# 0    498
# 1    303
# Name: count, dtype: int64

# %%
df['icu_admission']=df['icu_admission'].replace({'Yes':1,'No':0}).astype(int)

# %%
df['icu_admission'].value_counts()
# Out:
# icu_admission
# 0    647
# 1    154
# Name: count, dtype: int64

# %%
df['room_type']=df['room_type'].replace({'General Ward':0,'Semi-Private':1,'Private':2}).astype(int)

# %%
df['room_type'].value_counts()
# Out:
# room_type
# 0    319
# 1    280
# 2    202
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 801 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       801 non-null    int64
#  1   age                          801 non-null    int64
#  2   insurance_type               801 non-null    object
#  3   diagnosis_type               801 non-null    int64
#  4   procedures_count             801 non-null    int64
#  5   surgery_done                 801 non-null    int64
#  6   icu_admission                801 non-null    int64
#  7   length_of_stay_days          801 non-null    int64
#  8   medications_count            801 non-null    int64
#  9   room_type                    801 non-null    int64
#  10  predicted_hospital_bill_inr  801 non-null    float64
# dtypes: float64(1), int64(9), object(1)
# memory usage: 75.1+ KB

# %%
#getting info about columns so that we can define x an y variable
df.columns
# Out:
# Index(['gender', 'age', 'insurance_type', 'diagnosis_type', 'procedures_count',
#        'surgery_done', 'icu_admission', 'length_of_stay_days',
#        'medications_count', 'room_type', 'predicted_hospital_bill_inr'],
#       dtype='object')

# %%
# define y and x for testing and training
y=df['predicted_hospital_bill_inr']
x=df[['gender', 'age', 'insurance_type', 'diagnosis_type', 'procedures_count',
       'surgery_done', 'icu_admission', 'length_of_stay_days',
       'medications_count', 'room_type']]

# %%
#split data
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=2529)

# %%
#select model
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %%
#train the model
# Ensure 'insurance_type' is numerical before training
x_train['insurance_type'] = x_train['insurance_type'].replace({'Government': 0, 'Private': 1}).astype(int)

model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
#intercept and coefficients
model.intercept_,model.coef_
# Out:
# (np.float64(5712.106820048852),
#  array([-3.02052326e+02,  3.12833990e+00,  2.01625982e+02, -3.15100687e+01,
#          3.02866666e+03,  1.91080679e+04,  1.59314117e+04,  1.96571422e+03,
#          5.21738530e+02,  5.20586833e+03]))

# %%
#prediction
# Ensure 'insurance_type' is numerical before prediction
x_test['insurance_type'] = x_test['insurance_type'].replace({'Government': 0, 'Private': 1}).astype(int)

y_pred=model.predict(x_test)

# %%
#evaluate
from sklearn.metrics import mean_absolute_percentage_error
mean_absolute_percentage_error(y_test,y_pred)
# Out:
# 0.0788917130221707

# %%
# Encode 'insurance_type' column
df['insurance_type'] = df['insurance_type'].replace({'Government': 0, 'Private': 1}).astype(int)

# %%
import statsmodels.api as sm
x_const = sm.add_constant(x)
print(sm.OLS(y,x_const).fit().summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:     predicted_hospital_bill_inr   R-squared:                       0.948
# Model:                                     OLS   Adj. R-squared:                  0.948
# Method:                          Least Squares   F-statistic:                     1445.
# Date:                         Wed, 09 Jul 2025   Prob (F-statistic):               0.00
# Time:                                 04:35:56   Log-Likelihood:                -7945.5
# No. Observations:                          801   AIC:                         1.591e+04
# Df Residuals:                              790   BIC:                         1.596e+04
# Df Model:                                   10
# Covariance Type:                     nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ## Project Introduction: Hospital Bill Prediction for MediCarePlus
#
# This project focuses on developing a machine learning model to predict hospital bills for MediCarePlus patients. The goal is to leverage historical patient data to build a predictive tool that can estimate the cost of hospitalization based on various factors.
#
# The dataset used in this project includes information such as patient demographics (gender, age), insurance type, diagnosis, the number of procedures and medications, whether surgery was performed or ICU admission was required, the length of hospital stay, and the type of room occupied.
#
# By analyzing the relationships between these features and the final hospital bill amount, the machine learning model aims to provide accurate cost predictions. This can be valuable for various applications, including financial planning for both patients and the healthcare provider, optimizing resource allocation, and potentially identifying factors that significantly influence hospital costs. This is a regression problem, as the model is predicting a continuous numerical value (the hospital bill amount).
